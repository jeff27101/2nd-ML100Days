# %% [markdown]
# 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 1. 你選的這組資料為何重要
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 這組資料想解決的問題如何評估
#
# Ans:
#
# Kaggle - LANL Earthquake Prediction
# 這個競賽的目的是想預測何時地震即將來臨，地震預報越精確越能保護人的生命安全降低災害所造成的危害
# 本次競賽由Los Alamos National Laboratory主辦，提供實驗室模擬地震的數據，希望能夠利機器學習的方法，從量測到的應力資料預測出地震幾秒後發生(when)。屬於時間序列，預測數值的競賽
# 訓練的數據包含：
# acoustic_data - the seismic signal [int16]
# time_to_failure - the time (in seconds) until the next laboratory earthquake [float64]
# 評估的方式為：
# the mean absolute error between the predicted time remaining before the next lab earthquake and the act remaining time
#
# 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# Ans:
#
# 假設提升業績可以透過減少空車率來執行
# 可以搜集乘客搭乘的紀錄進行數據分析來給車手建議，讓車手不用盲目市區繞轉有效轉往潛在乘客的區域
# 搜集的資料可以為: 1.乘客的上車地點 2.時間點 3.天氣
# 可以評估空車率和業績

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.062

# %%
def mean_squared_error(y, yp):

    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 266.361
# The Mean absolute error is 13.062
